# %%
from codes.detection import *
import os
import cv2
import matplotlib.pyplot as plt

# %%
# test img 1 cluster 방식
path = os.path.join(os.getcwd(), 'img/test_img_1.png')
st = time.time()
imgs = Img_localize(path, 4)
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 0.051

# %%
# test img 2 claster 방식
path = os.path.join(os.getcwd(), 'img/test_img_2.png')
st = time.time()
imgs = Img_localize(path, 20, "cluster")
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 0.364

# %%
# test img 2 absorption 방식
path = os.path.join(os.getcwd(), 'img/test_img_2.png')
st = time.time()
imgs = Img_localize(path, 20, "absorption")
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 1.173
